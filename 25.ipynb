# %% [markdown]
# The Fibonacci sequence is defined by the recurrence relation:
#
# Fn = Fn−1 + Fn−2, where F1 = 1 and F2 = 1.
# Hence the first 12 terms will be:
#
# F1 = 1
# F2 = 1
# F3 = 2
# F4 = 3
# F5 = 5
# F6 = 8
# F7 = 13
# F8 = 21
# F9 = 34
# F10 = 55
# F11 = 89
# F12 = 144
# The 12th term, F12, is the first term to contain three digits.
#
# What is the index of the first term in the Fibonacci sequence to contain 1000 digits?

# %%
fibs = [1.0, 1.0]
while fibs[-1] != float('inf'):
    fibs.append(fibs[-1] + fibs[-2])

# %%
for i, v in enumerate(fibs):
    print(i,v)
# Out:
# 0 1.0
# 1 1.0
# 2 2.0
# 3 3.0
# 4 5.0
# 5 8.0
# 6 13.0
# 7 21.0
# 8 34.0
# 9 55.0
# 10 89.0
# 11 144.0
# 12 233.0
# 13 377.0
# 14 610.0
# 15 987.0
# 16 1597.0
# 17 2584.0
# 18 4181.0
# 19 6765.0
# 20 10946.0
# 21 17711.0
# 22 28657.0
# 23 46368.0
# 24 75025.0
# 25 121393.0
# 26 196418.0
# 27 317811.0
# 28 514229.0
# 29 832040.0
# 30 1346269.0
# 31 2178309.0
# 32 3524578.0
# 33 5702887.0
# 34 9227465.0
# 35 14930352.0
# 36 24157817.0
# 37 39088169.0
# 38 63245986.0
# 39 102334155.0
# 40 165580141.0
# 41 267914296.0
# 42 433494437.0
# 43 701408733.0
# 44 1134903170.0
# 45 1836311903.0
# 46 2971215073.0
# 47 4807526976.0
# 48 7778742049.0
# 49 12586269025.0
# 50 20365011074.0
# 51 32951280099.0
# 52 53316291173.0
# 53 86267571272.0
# 54 139583862445.0
# 55 225851433717.0
# 56 365435296162.0
# 57 591286729879.0
# 58 956722026041.0
# 59 1548008755920.0
# 60 2504730781961.0
# 61 4052739537881.0
# 62 6557470319842.0
# 63 10610209857723.0
# 64 17167680177565.0
# 65 27777890035288.0
# ...

# %%
nums = [(16, 4)] # index, num of digits
while nums[-1][1] <= 1000:
    if len(nums) < 5:
        nums.append((nums[-1][0]+5, nums[-1][1]+1))
    else:
        if nums[-5][1] == 4:
            nums.append((nums[-1][0]+4, nums[-1][1]+1))
        else:
            nums.append((nums[-1][0]+5, nums[-1][1]+1))

# %%
nums[-5:]
# Out:
# [(4980, 997), (4985, 998), (4990, 999), (4995, 1000), (5000, 1001)]

# %%
import sys
sys.float_info.max
# Out:
# 1.7976931348623157e+308

# %%
fibs[-2] - sys.float_info.max
# Out:
# -4.90703911098917e+307
