# %% [markdown]
# The series, $1^1 + 2^2 + 3^3 + ... + 10^{10} = 10405071317$.
#
# Find the last ten digits of the series, $1^1 + 2^2 + 3^3 + ... + 1000^{1000}$.

# %%
print([i**i for i in range(1,11)],"=", 10405071317)
# Out:
# [1, 4, 27, 256, 3125, 46656, 823543, 16777216, 387420489, 10000000000] = 10405071317

# %%
s = sum([i**i for i in range(1000)])
print(len(str(s)))
str(s)[-10:]
# Out:
# 2997
# '9110846701'

# %%
len(str(1000**1000
# Out:
# ...

# %%
# Out:
# '9110846701'

# %%
type(s)
# Out:
# int

# %%
long(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-cdb8293dd505> in <module>
# ----> 1 long(s)
#
# NameError: name 'long' is not defined
