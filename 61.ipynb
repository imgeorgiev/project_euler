# %% [markdown]
# Triangle, square, pentagonal, hexagonal, heptagonal, and octagonal numbers are all figurate (polygonal) numbers and are generated by the following formulae:
#
# Triangle	--- 	$P_{3,n} = \dfrac{n(n+1)}{2}$ --- 1, 3, 6, 10, 15, ...
#
# Square --- $P_{4,n} = n^2$ --- 1, 4, 9, 16, 25, ...
#
# Pentagonal --- $P_{5,n} = \dfrac{n(3n−1)}{2}$ --- 1, 5, 12, 22, 35, ...
#
# Hexagonal --- $P_{6,n} = n(2n−1)$ --- 1, 6, 15, 28, 45, ...
#
# Heptagonal --- $P_{7,n} = \dfrac{n(5n−3)}{2}$ --- 1, 7, 18, 34, 55, ...
#
# Octagonal --- $P_{8,n} = n(3n−2)$ --- 1, 8, 21, 40, 65, ...
#
# The ordered set of three 4-digit numbers: 8128, 2882, 8281, has three interesting properties.
#
# 1. The set is cyclic, in that the last two digits of each number is the first two digits of the next number (including the last number with the first).
# 2. Each polygonal type: triangle ($P_{3,127}=8128$), square ($P_{4,91}=8281$), and pentagonal ($P_{5,44}=2882$), is represented by a different number in the set.
# 3. This is the only set of 4-digit numbers with this property.
#
# Find the sum of the only ordered set of six cyclic 4-digit numbers for which each polygonal type: triangle, square, pentagonal, hexagonal, heptagonal, and octagonal, is represented by a different number in the set.

# %%
import math

def triangle(num):
    test = (-1 + math.sqrt(1+8*num))/2
    if test % 1.0 == 0.0:
        return True, int(test)
    return False, 0

assert triangle(8128) == (True, 127)

def square(num):
    test = math.sqrt(num)
    if test % 1.0 == 0.0:
        return True, int(test)
    return False, 0

assert square(8281) == (True, 91)

def pentagonal(num):
    test = (1 + math.sqrt(1+24*num))/6
    if test % 1.0 == 0.0:
        return True, int(test)
    return False, 0

assert pentagonal(2882) == (True, 44)

def hexagonal(num):
    test = (1 + math.sqrt(1+8*num))/4
    if test % 1.0 == 0.0:
        return True, int(test)
    return False, 0

assert hexagonal(28*(2*28-1)) == (True, 28)

def heptagonal(num):
    test = (3 + math.sqrt(9+40*num))/10
    if test % 1.0 == 0.0:
        return True, int(test)
    return False, 0

assert heptagonal(24*(5*24 - 3)/2) == (True, 24)

def octagonal(num):
    test = (2 + math.sqrt(4+12*num))/6
    if test % 1.0 == 0.0:
        return True, int(test)
    return False, 0

assert octagonal(17*(3*17-2)) == (True, 17)

def to_digit_list(num):
    digits = []
    while num>0:
        digits.append(num%10)
        num = num//10
    return digits[::-1]

# %%
to_digit_list(213)
# Out:
# [2, 1, 3]

# %%
# %%time

from tqdm import tqdm
from itertools import cycle, combinations, permutations, product

# test example from question
n_digits = 4
target_set = 3
target_digits = target_set*(n_digits//2)

for i in permutations(range(10,100), target_set):
    num_set = []
    for j in range(target_set):
        num_set.append(i[j] * 100 + i[(j+1)%target_set])
        
    # now test all possible permutations
    for perms in permutations(num_set):
        if triangle(perms[0])[0] and square(perms[1])[0] and pentagonal(perms[2])[0]:
            print("Original", i)
            print("Got a hit with numbers", perms)
            print("Their sum is", sum(perms))
            print("")
            break
# Out:
# 164661it [00:01, 157210.43it/s]
# Original (28, 82, 81)
# Got a hit with numbers (8128, 8281, 2882)
# Their sum is 19291
# 578397it [00:03, 165201.29it/s]
# Original (81, 28, 82)
# Got a hit with numbers (8128, 8281, 2882)
# Their sum is 19291
#
# Original (82, 81, 28)
# Got a hit with numbers (8128, 8281, 2882)
# Their sum is 19291
# 704880it [00:04, 166671.91it/s]
# CPU times: user 4.21 s, sys: 29.3 ms, total: 4.24 s
# Wall time: 4.23 s

# %%
# %%time

from tqdm import tqdm
from itertools import cycle, combinations, permutations, product

# test example from question
n_digits = 4
target_set = 6
target_digits = target_set*(n_digits//2)

for i in permutations(range(10,100), target_set):
    num_set = []
    for j in range(target_set):
        num_set.append(i[j] * 100 + i[(j+1)%target_set])
        
    # now test all possible permutations
    for perms in permutations(num_set):
        if triangle(perms[0])[0] and square(perms[1])[0] and pentagonal(perms[2])[0]:
            print("Original", i)
            print("Got a hit with numbers", perms)
            print("Their sum is", sum(perms))
            print("")
            break
# Out:
# Original (10, 11, 12, 15, 21, 45)
# Got a hit with numbers (2145, 1521, 4510, 1011, 1112, 1215)
# Their sum is 11514
#
# Original (10, 11, 12, 25, 21, 45)
# Got a hit with numbers (2145, 1225, 4510, 1011, 1112, 2521)
# Their sum is 12524
#
# Original (10, 11, 12, 25, 56, 45)
# Got a hit with numbers (2556, 1225, 4510, 1011, 1112, 5645)
# Their sum is 16059
#
# Original (10, 11, 12, 25, 90, 45)
# Got a hit with numbers (9045, 1225, 4510, 1011, 1112, 2590)
# Their sum is 19493
#
# Original (10, 11, 12, 37, 21, 45)
# Got a hit with numbers (2145, 3721, 4510, 1011, 1112, 1237)
# Their sum is 13736
#
# Original (10, 11, 12, 47, 53, 29)
# Got a hit with numbers (4753, 5329, 1247, 1011, 1112, 2910)
# Their sum is 16362
